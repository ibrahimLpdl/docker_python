# %% [markdown]
#  Les KPI, sont des indicateurs permettant de suivre l'évolution d'une stratégie  dans le but d'atteindre des objectifs.

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('sample_data/eval_data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  3376 non-null   object
#  5   item_price          4522 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
data.describe()
# Out:
#         Unnamed: 0     order_id     quantity
# count  4622.000000  4622.000000  4622.000000
# mean   2310.500000   927.254868     1.075725
# std    1334.400802   528.890796     0.410186
# min       0.000000     1.000000     1.000000
# 25%    1155.250000   477.250000     1.000000
# 50%    2310.500000   926.000000     1.000000
# 75%    3465.750000  1393.000000     1.000000
# max    4621.000000  1834.000000    15.000000

# %%
data.ndim
# Out:
# 2

# %%
data
# Out:
#       Unnamed: 0  ...  item_price
# 0              0  ...         NaN
# 1              1  ...      $3.39
# 2              2  ...      $3.39
# 3              3  ...         NaN
# 4              4  ...     $16.98
# ...          ...  ...         ...
# 4617        4617  ...     $11.75
# 4618        4618  ...     $11.75
# 4619        4619  ...     $11.25
# 4620        4620  ...      $8.75
# 4621        4621  ...      $8.75
#
# [4622 rows x 6 columns]

# %%
data[0:10]
# Out:
#    Unnamed: 0  ...  item_price
# 0           0  ...         NaN
# 1           1  ...      $3.39
# 2           2  ...      $3.39
# 3           3  ...         NaN
# 4           4  ...     $16.98
# 5           5  ...     $10.98
# 6           6  ...      $1.69
# 7           7  ...     $11.75
# 8           8  ...      $9.25
# 9           9  ...      $9.25
#
# [10 rows x 6 columns]

# %% [markdown]
# Chicken Bowl est le produit le plus commander

# %%
data.groupby(by=['item_name']).sum().groupby(level=[0]).cumsum()
# Out:
#                                        Unnamed: 0  order_id  quantity
# item_name
# 6 Pack Soft Drink                          130318     52322        55
# Barbacoa Bowl                              134264     53972        66
# Barbacoa Burrito                           185979     74718        91
# Barbacoa Crispy Tacos                       13825      5613        12
# Barbacoa Salad Bowl                         24161      9708        10
# Barbacoa Soft Tacos                         46454     18725        25
# Bottled Water                              439354    175944       211
# Bowl                                         1118       472         4
# Burrito                                      3734      1550         6
# Canned Soda                                189915     76396       126
# Canned Soft Drink                          759990    304753       351
# Carnitas Bowl                              156599     62742        71
# ...

# %% [markdown]
# le total d'item commander est de 4972

# %%
data['quantity'].sum()
# Out:
# 4972
